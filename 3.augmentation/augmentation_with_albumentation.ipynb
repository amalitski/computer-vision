# %%
from google.colab import drive
drive.mount('/content/drive')
dir = "/content/drive/MyDrive/Colab Notebooks/computer-vision/data/augmentation/bill gates/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Albumentation

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def show_images(imgs, transform=None, columns=5):
  if transform is not None:
    imgs = []
    for i in images:
      alb = transform(image=i)
      imgs.append(alb['image'])
    random.seed(42)
  plt.figure(figsize=(20,10))
  for i, image in enumerate(imgs):
      plt.subplot(len(images) / columns + 1, columns, i + 1)
      plt.imshow(image)

images = []
for img_path in glob.glob(dir + '*.jpeg'):
  image = cv2.imread(img_path)
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  images.append(image)

print("Source images:")
show_images(images)
# Out:
# Source images:

# %%
transform = A.Compose(
    [
        A.HorizontalFlip(p=0.5),
        A.ShiftScaleRotate(p=0.5),
    ]
)
show_images(images, transform=transform)

# %%
transform = A.Compose(
    [
        A.HorizontalFlip(p=0.5),
        A.CLAHE(always_apply=False, p=1.0, clip_limit=(1, 70), tile_grid_size=(8, 8)),
    ]
)
show_images(images, transform=transform)

# %%
transform = A.Compose(
    [
        A.ToGray(always_apply=False, p=1.0),
        A.CLAHE(always_apply=False, p=1.0, clip_limit=(1, 70), tile_grid_size=(8, 8)),
    ]
)
show_images(images, transform=transform)
